# %%
import numpy as np
import clima_anom as ca
import cartopy
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %%
hgt_dir = '../data/Hgt_500hPa_Jan80_Dec19.nc'

# %%
hgt_data = ca.read_netcdf(hgt_dir,2)
# Out:
# hgt : (480, 1, 73, 144)
# lat : (73,)
# level : (1,)
# lon : (144,)
# time : (480,)

# %%
lat = hgt_data['lat']
lon = hgt_data['lon'] - 180

# %%
hgt_data['time'][0],hgt_data['time'][-1]
# Out:
# (cftime.DatetimeGregorian(1980, 1, 1, 0, 0, 0, 0),
#  cftime.DatetimeGregorian(2019, 12, 1, 0, 0, 0, 0))

# %%
hgt_dictionary = ca.clima_anom(hgt_data['hgt'][:,0,:,:])
# Out:
# Keys level 1:  dict_keys(['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'ago', 'sep', 'oct', 'nov', 'dec'])
# keys level 2:  dict_keys(['data', 'clim', 'anom'])
#
# Numbers of years:  40
# Numbers of months:  480

# %%
lon2d, lat2d = np.meshgrid(lon, lat)

# %%
levels = np.arange(4600,6100,100)
cmap = plt.cm.RdBu_r

proj = ccrs.PlateCarree()

fig = plt.figure(figsize=(8,28),dpi=150)
ax1 = plt.subplot(12,2,1, projection = proj)
ax2 = plt.subplot(12,2,2, projection = proj, sharex=ax1, sharey=ax1)
ax3 = plt.subplot(12,2,3, projection = proj, sharex=ax1, sharey=ax1)
ax4 = plt.subplot(12,2,4, projection = proj, sharex=ax1, sharey=ax1)
ax5 = plt.subplot(12,2,5, projection = proj, sharex=ax1, sharey=ax1)
ax6 = plt.subplot(12,2,6, projection = proj, sharex=ax1, sharey=ax1)
ax7 = plt.subplot(12,2,7, projection = proj, sharex=ax1, sharey=ax1)
ax8 = plt.subplot(12,2,8, projection = proj, sharex=ax1, sharey=ax1)
ax9 = plt.subplot(12,2,9, projection = proj, sharex=ax1, sharey=ax1)
ax10 = plt.subplot(12,2,10, projection = proj, sharex=ax1, sharey=ax1)
ax11 = plt.subplot(12,2,11, projection = proj, sharex=ax1, sharey=ax1)
ax12 = plt.subplot(12,2,12, projection = proj, sharex=ax1, sharey=ax1)
#========================================================================================================
#========================================================================================================
ax1.coastlines()
a1 = ax1.contourf(lon2d, lat2d, hgt_dictionary['jan']['clim'][0,:,:],levels=levels,cmap=cmap)
ax1.title.set_text('January Climatology')
gl = ax1.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax2.coastlines()
ax2.contourf(lon2d, lat2d, hgt_dictionary['feb']['clim'][0,:,:],levels=levels,cmap=cmap)
ax2.title.set_text('February Climatology')
gl = ax2.gridlines(crs = proj,draw_labels=False,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax3.coastlines()
ax3.contourf(lon2d, lat2d, hgt_dictionary['mar']['clim'][0,:,:],levels=levels,cmap=cmap)
ax3.title.set_text('March Climatology')
gl = ax3.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax4.coastlines()
ax4.contourf(lon2d, lat2d, hgt_dictionary['apr']['clim'][0,:,:],levels=levels,cmap=cmap)
ax4.title.set_text('April Climatology')
gl = ax4.gridlines(crs = proj,draw_labels=False,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax5.coastlines()
ax5.contourf(lon2d, lat2d, hgt_dictionary['may']['clim'][0,:,:],levels=levels,cmap=cmap)
ax5.title.set_text('May Climatology')
gl = ax5.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax6.coastlines()
ax6.contourf(lon2d, lat2d, hgt_dictionary['jun']['clim'][0,:,:],levels=levels,cmap=cmap)
ax6.title.set_text('June Climatology')
gl = ax6.gridlines(crs = proj,draw_labels=False,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax7.coastlines()
ax7.contourf(lon2d, lat2d, hgt_dictionary['jul']['clim'][0,:,:],levels=levels,cmap=cmap)
ax7.title.set_text('July Climatology')
gl = ax7.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax8.coastlines()
ax8.contourf(lon2d, lat2d, hgt_dictionary['ago']['clim'][0,:,:],levels=levels,cmap=cmap)
ax8.title.set_text('August Climatology')
gl = ax8.gridlines(crs = proj,draw_labels=False,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax9.coastlines()
ax9.contourf(lon2d, lat2d, hgt_dictionary['sep']['clim'][0,:,:],levels=levels,cmap=cmap)
ax9.title.set_text('September Climatology')
gl = ax9.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.bottom_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax10.coastlines()
ax10.contourf(lon2d, lat2d, hgt_dictionary['oct']['clim'][0,:,:],levels=levels,cmap=cmap)
ax10.title.set_text('October Climatology')
gl = ax10.gridlines(crs = proj,draw_labels=False,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax11.coastlines()
ax11.contourf(lon2d, lat2d, hgt_dictionary['nov']['clim'][0,:,:],levels=levels,cmap=cmap)
ax11.title.set_text('November Climatology')
gl = ax11.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
ax12.coastlines()
ax12.contourf(lon2d, lat2d, hgt_dictionary['dec']['clim'][0,:,:],levels=levels,cmap=cmap)
ax12.title.set_text('December Climatology')
gl = ax12.gridlines(crs = proj,draw_labels=True,linewidth=0.6,color='gray',alpha=0.6,linestyle='--')
gl.top_labels = False
gl.right_labels = False
gl.left_labels = False
gl.xlabel_style = {'size': 8, 'color': 'black'}
gl.ylabel_style = {'size': 8, 'color': 'black'}
#========================================================================================================
#========================================================================================================
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, hspace=0.03, wspace=0.05)

plt.savefig('../fig/Monthly_Climatology.png',transparent = False,bbox_inches ='tight',pad_inches = 0.1)
